# %%
#Problem 51

# %%
x = var('x')

# %%
def f(x): return (1/(1+x^2))

# %%
plot(f(x),(x,-20,20), fill=true, color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
int = integral(f(x), x, -oo, oo)

# %%
int
# Out:
# pi
